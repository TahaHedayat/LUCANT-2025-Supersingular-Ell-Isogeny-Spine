# %% [markdown]
# This notebook allows the user to obtain visualizationsof $\mathcal{G}_\ell(\mathbb{F}_p)$,$\mathcal{S}_\ell^p$, $\mathcal{G}_\ell(\overline{\mathbb{F}}_p)$.
#
# Over $\mathbb{F}_p$, the vertex labels are (j-invariant, c4-invariant, c6-invariant), unless the characteristic is 2 or 3, in which case the vertex labels are (j-invariant, a-invariants)

# %%
load("graph_functions.sage")
from sage.modular.ssmod.ssmod import Phi_polys

p = ZZ(input("field characteristic p ="))
l = ZZ(input("isogeny degree l ="))

print("Fp l-isogeny graph")
G = build_isogeny_graph_over_Fp(p, l)
G.plot()
# Out:
# field characteristic p = 71
# isogeny degree l = 2
# Fp l-isogeny graph
# Graphics object consisting of 56 graphics primitives

# %%
H = build_isogeny_graph_over_Fpbar(p, l)
print("The spine")
S = build_spine(p,l,H)
S.plot()
# Out:
# The spine
# Graphics object consisting of 35 graphics primitives

# %%
print("Fp-bar l-isogeny graph")
H.plot()
# Out:
# Fp-bar l-isogeny graph
# Graphics object consisting of 35 graphics primitives
